# %% [markdown]
# # Import library

# %%
# !pip install ultralytics
from ultralytics import YOLO
import cv2
import random
import os
# Out:
# ...
# WARNING: Ignoring invalid distribution - (c:\python310\lib\site-packages)
# WARNING: Ignoring invalid distribution -ip (c:\python310\lib\site-packages)
# WARNING: Ignoring invalid distribution -p (c:\python310\lib\site-packages)
# WARNING: Ignoring invalid distribution - (c:\python310\lib\site-packages)
# WARNING: Ignoring invalid distribution -ip (c:\python310\lib\site-packages)
# WARNING: Ignoring invalid distribution -p (c:\python310\lib\site-packages)

# %% [markdown]
# # Evaluate

# %%
model = YOLO('./runs/detect/train5_Backup_11-12-2023/weights/best.pt') # change the model to which you want to evaluate
metrics = model.val(imgsz=960, data="./LogoDept_prep.yaml", device='cpu') # It run fine on colab, but runing on my PC using cuda got an error, so I use cpu instead.
metrics.box.map    # map50-95
metrics.box.map50  # map50
metrics.box.map75  # map75
metrics.box.maps   # a list contains map50-95 of each category
# Out:
# Ultralytics YOLOv8.0.227 🚀 Python-3.10.2 torch-2.1.1+cu121 CPU (AMD Ryzen 7 5800HS with Radeon Graphics)
# Model summary (fused): 168 layers, 11169680 parameters, 0 gradients, 29.7 GFLOPs
# val: Scanning C:\Users\chant\Desktop\IntroDigImage_BrandDection_withYOLOv8\datasets\LogoDet_prep\labels\val.cache... 192 images, 0 backgrounds, 0 corrupt: 100%|██████████| 192/192 [00:00<?, ?it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 12/12 [01:13<00:00,  6.13s/it]
#                    all        192        192      0.641      0.511      0.554      0.265
#                    BMW        192          3      0.789      0.333      0.564      0.295
#                BUGATTI        192          3      0.782      0.333      0.376      0.264
#                mclaren        192          3      0.963          1      0.995      0.311
#               Maserati        192          3      0.083      0.111      0.121     0.0664
# ...

# %% [markdown]
# # Predict

# %%
source = './datasets/LogoDet_prep/images/val'

results = model(source, save=True, imgsz=960)
# Out:
# image 1/192 c:\Users\chant\Desktop\IntroDigImage_BrandDection_withYOLOv8\datasets\LogoDet_prep\images\val\Akg1.jpeg: 960x640 1 Balenciaga, 1 prada, 303.0ms
# image 2/192 c:\Users\chant\Desktop\IntroDigImage_BrandDection_withYOLOv8\datasets\LogoDet_prep\images\val\Akg2.jpg: 960x960 (no detections), 384.9ms
# image 3/192 c:\Users\chant\Desktop\IntroDigImage_BrandDection_withYOLOv8\datasets\LogoDet_prep\images\val\Akg3.jpeg: 960x704 1 AKG, 1 game boy, 1 Columbia, 301.0ms
# image 4/192 c:\Users\chant\Desktop\IntroDigImage_BrandDection_withYOLOv8\datasets\LogoDet_prep\images\val\Apple1.jpeg: 544x960 1 Apple, 224.1ms
# image 5/192 c:\Users\chant\Desktop\IntroDigImage_BrandDection_withYOLOv8\datasets\LogoDet_prep\images\val\Apple2.jpeg: 736x960 (no detections), 302.9ms
# image 6/192 c:\Users\chant\Desktop\IntroDigImage_BrandDection_withYOLOv8\datasets\LogoDet_prep\images\val\Apple3.jpeg: 960x832 (no detections), 338.0ms
# ...

# %%
predict_imgs_path = os.listdir('./runs/detect/predict')
random_imgs_path = random.choices(predict_imgs_path, k=5)

window_name = 'preview'
for name in random_imgs_path:
    image = cv2.imread(os.path.join('./runs/detect/predict', name))
    cv2.imshow(window_name, image)
    cv2.waitKey()
    cv2.destroyAllWindows()
